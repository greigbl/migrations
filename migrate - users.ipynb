# %%
from src.helper import export_users, import_users
import pandas as pd

# %%
DIR = "migrations"
USER_FILE = "user_export.csv"
initial_password = "aBcD654321"

# %%
exported_users = export_users()

# %%
exported_users

# %%
exported_users.to_csv(f"{DIR}/{USER_FILE}", index=False)

# %%
imported_users = import_users(DIR=DIR, USER_EXPORT_FILE=USER_FILE, PASSWORD=initial_password)

# %%
pd.DataFrame(imported_users)
